# %% [markdown]
# Testes de normalidade

# %%
rna_precision = [0.98138777, 0.98144824, 0.98190333, 0.98241636, 0.98138132, 0.97993475,
 0.98213971, 0.97998337, 0.98211317, 0.98186407]
rna_recall = [0.99852113, 0.99896153, 0.99859725, 0.99880385, 0.9993095,  0.99945086,
 0.99889629, 0.99953785, 0.99888541, 0.99845588]
rfc_precision =[0.98343195, 0.98336882, 0.98374353, 0.98418016, 0.9833017, 0.98349644,
 0.98340748, 0.98352274, 0.98332745, 0.98516389]
rfc_recall = [0.99851569, 0.99948348, 0.99988039, 0.99985864, 0.99987495, 0.99988582,
 0.99991301, 0.99989126, 0.99984776, 0.99681934]

# %%
from scipy.stats import shapiro

# %%
shapiro(rna_precision), shapiro(rna_recall),shapiro(rfc_precision),shapiro(rfc_recall)
# Out:
# (ShapiroResult(statistic=0.8406535983085632, pvalue=0.04492700472474098),
#  ShapiroResult(statistic=0.9248554110527039, pvalue=0.399234801530838),
#  ShapiroResult(statistic=0.6940319538116455, pvalue=0.0007458494510501623),
#  ShapiroResult(statistic=0.5934574007987976, pvalue=4.621819607564248e-05))

# %%
import seaborn as sns

# %%
sns.displot(rfc_precision, kind="kde")
